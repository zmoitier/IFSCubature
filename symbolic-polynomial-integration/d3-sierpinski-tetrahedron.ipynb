# %% [markdown]
# # Sierpiński tetrahedron

# %%
import sympy as sy

import src

# %%
def sierpinski_tetrahedron(factor: sy.Expr | None = None) -> src.SelfAffineSet:
    """Return the Sierpinski tetrahedron."""

    if factor is None:
        factor = sy.Rational(1, 2)

    ifs = [
        src.contractive_similarity(factor, sy.eye(3), sy.Matrix(p))
        for p in [
            (1, 0, -sy.sqrt(2) / 2),
            (-1, 0, -sy.sqrt(2) / 2),
            (0, 1, sy.sqrt(2) / 2),
            (0, -1, sy.sqrt(2) / 2),
        ]
    ]

    return src.SelfAffineSet(ifs, src.uniform_measure(len(ifs)), 3)

# %%
attractor = sierpinski_tetrahedron(sy.Rational(1, 2))

# %%
src.render_chaos_game(attractor, 10_000)

# %%
tot_deg_max = 4

values = src.compute_polynomial_integral(attractor, tot_deg_max)

src.display_values(
    values, attractor.space_dim, variables=sy.symbols("x y z", real=True)
)
# Out:
# $\displaystyle \int_\Gamma 1\, \mathrm{d}\mu(\boldsymbol{x}) = 1 $
# $\displaystyle \int_\Gamma x\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma z\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{1}{6} $
# $\displaystyle \int_\Gamma x y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x z\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma y^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{1}{6} $
# $\displaystyle \int_\Gamma y z\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma z^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{1}{6} $
# $\displaystyle \int_\Gamma x^{3}\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x^{2} y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x^{2} z\, \mathrm{d}\mu(\boldsymbol{x}) = - \frac{\sqrt{2}}{28} $
# ...

# %%
# src.export_to_file(values, attractor, "d3-sierpinski-tetrahedron")
