# %% [markdown]
# # Fat Sierpiński triangle

# %%
import numpy as np
import sympy as sy

import src

# %%
def sierpinski_triangle(factor: sy.Expr | None = None) -> src.SelfAffineSet:
    """Return the Sierpinski triangle."""

    if factor is None:
        factor = sy.Rational(1, 2)

    ifs = [
        src.contractive_similarity(factor, sy.eye(2), sy.Matrix(p))
        for p in [
            (1, 0),
            (sy.Rational(-1, 2), sy.sqrt(3) / 2),
            (sy.Rational(-1, 2), -sy.sqrt(3) / 2),
        ]
    ]

    return src.SelfAffineSet(ifs, src.uniform_measure(len(ifs)), 2)

# %%
attractor = sierpinski_triangle((sy.sqrt(5) - 1) / 2)

# a = (17 + 3 * sy.sqrt(33)) ** sy.Rational(1, 3)
# attractor = sierpinski_triangle(a / 3 - 2 / (3 * a) - sy.Rational(1, 3))

# %%
src.render_pre_attractor(
    attractor, np.array([[1, -0.5, -0.5], [0, np.sqrt(3) / 2, -np.sqrt(3) / 2]]), 3
)

# %%
src.render_chaos_game(attractor, 10_000)

# %%
tot_deg_max = 4

values = src.compute_polynomial_integral(attractor, tot_deg_max)

src.display_values(values, attractor.space_dim, variables=sy.symbols("x y", real=True))
# Out:
# $\displaystyle \int_\Gamma 1\, \mathrm{d}\mu(\boldsymbol{x}) = 1 $
# $\displaystyle \int_\Gamma x\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{-2 + \sqrt{5}}{2} $
# $\displaystyle \int_\Gamma x y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma y^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{-2 + \sqrt{5}}{2} $
# $\displaystyle \int_\Gamma x^{3}\, \mathrm{d}\mu(\boldsymbol{x}) = - \frac{-7 + 3 \sqrt{5}}{16} $
# $\displaystyle \int_\Gamma x^{2} y\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x y^{2}\, \mathrm{d}\mu(\boldsymbol{x}) = \frac{-7 + 3 \sqrt{5}}{16} $
# $\displaystyle \int_\Gamma y^{3}\, \mathrm{d}\mu(\boldsymbol{x}) = 0 $
# $\displaystyle \int_\Gamma x^{4}\, \mathrm{d}\mu(\boldsymbol{x}) = - \frac{3 \left(-110 + 49 \sqrt{5}\right)}{40} $
# ...

# %%
# src.export_to_file(values, attractor, "d2-sierpinski-triangle")
